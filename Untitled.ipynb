# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\TriciaToffey\\desktop\\GitHubs\\ETL_Project\\no_dog_etl'

# %%
df_orig=pd.read_csv("./Resources/dog_breed_characteristics.csv")
df_orig.head(5)
# Out:
#              BreedName AltBreedName    Group1     Group2  MaleWtKg  \
# 0        Affenpinscher          NaN       Toy  Companion       4.0
# 1         Afghan Hound          NaN  Sporting      Sight      28.0
# 2  African Hunting Dog          NaN       NaN        NaN      23.0
# 3     Airedale Terrier     Airedale   Terrier    Terrier      26.0
# 4               Akbash          NaN   Working   Guardian      53.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    Intelligence  Watchdog  MalaysiaGuardedDog  MalaysiaProhibitedDog  \
# 0          37.0       1.0                 NaN                    NaN
# ...

# %%
df_orig.columns
# Out:
# Index(['BreedName', 'AltBreedName', 'Group1', 'Group2', 'MaleWtKg',
#        'Temperment', 'AvgPupPrice', 'Intelligence', 'Watchdog',
#        'MalaysiaGuardedDog', 'MalaysiaProhibitedDog', 'MalaysiaPopularity',
#        'PopularityUS2017'],
#       dtype='object')

# %%
df=df_orig.drop(["AltBreedName", "MalaysiaGuardedDog", "MalaysiaProhibitedDog", "MalaysiaPopularity"], axis=1)

# %%
df.head()
# Out:
#              BreedName    Group1     Group2  MaleWtKg  \
# 0        Affenpinscher       Toy  Companion       4.0
# 1         Afghan Hound  Sporting      Sight      28.0
# 2  African Hunting Dog       NaN        NaN      23.0
# 3     Airedale Terrier   Terrier    Terrier      26.0
# 4               Akbash   Working   Guardian      53.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    Intelligence  Watchdog  PopularityUS2017
# 0          37.0       1.0             147.0
# 1          79.0       1.0              93.0
# 2           NaN       NaN               NaN
# 3          29.0       4.0              55.0
# ...

# %%
df.sort_values(by=['PopularityUS2017'])
# Out:
#                         BreedName    Group1    Group2  MaleWtKg  \
# 247     Yellow Labrador Retriever  Sporting       Gun      32.0
# 64   Chocolate Labrador Retriever  Sporting       Gun      32.0
# 31       Black Labrador Retriever  Sporting       Gun      32.0
# 143            Labrador Retriever  Sporting       Gun      32.0
# 209                      Shepherd   Herding   Herding      35.0
# ..                            ...       ...       ...       ...
# 198                   Sarplaninac   Working  Guardian      33.0
# 218       South Russian Ovtcharka   Herding   Herding      49.0
# 225                Thai Ridgeback     Hound     Sight      28.0
# 229                      Tosa Inu   Working  Guardian      65.0
# 249                   Mixed Breed       NaN       NaN       NaN
#
#                                             Temperment  AvgPupPrice  \
# 247  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# ...

# %%
df[['BreedName', 'PopularityUS2017']]
# Out:
#                            BreedName  PopularityUS2017
# 0                      Affenpinscher             147.0
# 1                       Afghan Hound              93.0
# 2                African Hunting Dog               NaN
# 3                   Airedale Terrier              55.0
# 4                             Akbash               NaN
# ..                               ...               ...
# 245               Wirehaired Terrier              99.0
# 246  Xoloitzcuintle/Mexican Hairless             143.0
# 247        Yellow Labrador Retriever               1.0
# 248         Yorkshire Terrier Yorkie               9.0
# 249                      Mixed Breed               NaN
#
# [250 rows x 2 columns]

# %%
df_sorted = df.sort_values(by=["PopularityUS2017"])
df_sorted.tail(25)
# Out:
#                              BreedName        Group1      Group2  MaleWtKg  \
# 120                           Hovawart       Working    Guardian      38.0
# 123                  Illyrian Sheepdog       Herding     Herding      40.0
# 133                              Jindo      Sporting    Northern      20.0
# 134                            Kai Dog  Non Sporting    Northern      18.0
# 135                  Karelian Bear Dog      Sporting    Northern      22.0
# 138                              Kishu      Sporting    Northern      20.0
# 139                           Klee Kai  Non Sporting    Northern       7.0
# 142                            Kyi Leo  Non Sporting   Companion       5.0
# 145                  Lancashire Heeler       Herding     Herding       5.0
# 151                   Maremma Sheepdog       Working    Guardian      38.0
# 153                              McNab       Herding     Herding      23.0
# ...

# %%
#df = df.loc[df['PopularityUS2017'].notnull()]

# %%
duplicates = df["PopularityUS2017"].value_counts().loc[lambda x:x>1]

# %%
duplicates =  df['PopularityUS2017'].value_counts().to_frame()
duplicates=duplicates.reset_index()
duplicates.head(25)
# Out:
#     index  PopularityUS2017
# 0    68.0                 4
# 1     1.0                 4
# 2   118.0                 4
# 3     2.0                 3
# 4     3.0                 2
# 5   122.0                 2
# 6    70.0                 2
# 7     7.0                 2
# 8    29.0                 2
# 9   130.0                 2
# 10   25.0                 2
# 11   95.0                 2
# 12   42.0                 2
# 13  113.0                 2
# 14  187.0                 2
# 15   99.0                 2
# 16   12.0                 2
# 17   80.0                 2
# 18   56.0                 2
# 19  179.0                 1
# 20   76.0                 1
# 21  158.0                 1
# 22  184.0                 1
# 23  140.0                 1
# 24  182.0                 1

# %%
duplicates=duplicates.loc[duplicates["PopularityUS2017"]>=2]
duplicates
# Out:
#     index  PopularityUS2017
# 0    68.0                 4
# 1     1.0                 4
# 2   118.0                 4
# 3     2.0                 3
# 4     3.0                 2
# 5   122.0                 2
# 6    70.0                 2
# 7     7.0                 2
# 8    29.0                 2
# 9   130.0                 2
# 10   25.0                 2
# 11   95.0                 2
# 12   42.0                 2
# 13  113.0                 2
# 14  187.0                 2
# 15   99.0                 2
# 16   12.0                 2
# 17   80.0                 2
# 18   56.0                 2

# %%
df_sorted = df.sort_values(by=["PopularityUS2017"])
#df_sorted.tail(25)
#There is no dog with PopularityUS2017 rank of 189

# %%
akc_df=pd.read_csv("index.csv")
#akc_df.head()

# %%
akc_df["Breed"].value_counts(ascending=False)
# Out:
# Dandie Dinmont Terriers    1
# Great Danes                1
# Belgian Malinois           1
# Wirehaired Vizslas         1
# Papillons                  1
#                           ..
# Setters (English)          1
# Beaucerons                 1
# Cirnechi dell’Etna         1
# Xoloitzcuintli             1
# Finnish Spitz              1
# Name: Breed, Length: 190, dtype: int64

# %%
df["BreedName"].value_counts(ascending=False)
# Out:
# Giant Schnauzer              2
# Miniature Poodle             1
# German Wirehaired Pointer    1
# Great Pyrenees               1
# Canaan Dog                   1
#                             ..
# English Shepherd             1
# American Eskimo Dog          1
# Karelian Bear Dog            1
# English Cocker Spaniel       1
# Bloodhound                   1
# Name: BreedName, Length: 249, dtype: int64

# %%
pop_select=akc_df.loc[akc_df['breed_rank']==190]
pop_select
# Out:
#      breed_id                 Breed  breed_rank
# 189       190  Norwegian Lundehunds         190

# %%
pop_select=df.loc[df['PopularityUS2017']==80]
pop_select
# Out:
#            BreedName   Group1     Group2  MaleWtKg  \
# 109  Giant Schnauzer  Working  Companion      38.0
# 202  Giant Schnauzer  Working    Herding      31.0
#
#                                             Temperment  AvgPupPrice  \
# 109  Dominant, Intelligent, Kind, Loyal, Powerful, ...       1250.0
# 202  Devoted, Good-natured, Intelligent, Lively, Pl...       1250.0
#
#      Intelligence  Watchdog  PopularityUS2017
# 109          28.0       6.0              80.0
# 202           NaN       NaN              80.0

# %%
df.at[109,'BreedName']   #[row,column] -- Giant Schnauzer (Companion)
df.at[202,'BreedName']   #[row,column] -- Giant Schnauzer (Herding)
# Out:
# 'Giant Schnauzer'

# %%
df.at[109,'BreedName']="Giant Schnauzer (Companion)"
df.at[202,'BreedName']="Giant Schnauzer (Herding)"

# %%
#df.at[109,'BreedName']   
df.at[202,'BreedName']
# Out:
# 'Giant Schnauzer (Herding)'

# %%
merged_df=akc_df.merge(df, how="left", left_on="breed_rank", right_on="PopularityUS2017")

# %%
merged_df  #characteristics database is missing #189
# Out:
#      breed_id                  Breed  breed_rank  \
# 0           1  Retrievers (Labrador)           1
# 1           1  Retrievers (Labrador)           1
# 2           1  Retrievers (Labrador)           1
# 3           1  Retrievers (Labrador)           1
# 4           2   German Shepherd Dogs           2
# ..        ...                    ...         ...
# 211       187     American Foxhounds         187
# 212       187     American Foxhounds         187
# 213       188               Sloughis         188
# 214       189      English Foxhounds         189
# 215       190   Norwegian Lundehunds         190
#
#                         BreedName        Group1      Group2  MaleWtKg  \
# 0        Black Labrador Retriever      Sporting         Gun      32.0
# 1    Chocolate Labrador Retriever      Sporting         Gun      32.0
# 2              Labrador Retriever      Sporting         Gun      32.0
# 3       Yellow Labrador Retriever      Sporting         Gun      32.0
# ...

# %%
merged_df.at[214,'BreedName']="English Foxhounds"

# %%
merged_df.isna().sum().sum()
# Out:
# 175

# %%
merged_df.drop(columns=['breed_id'])
# Out:
#                      Breed  breed_rank                     BreedName  \
# 0    Retrievers (Labrador)           1      Black Labrador Retriever
# 1    Retrievers (Labrador)           1  Chocolate Labrador Retriever
# 2    Retrievers (Labrador)           1            Labrador Retriever
# 3    Retrievers (Labrador)           1     Yellow Labrador Retriever
# 4     German Shepherd Dogs           2           German Shepherd Dog
# ..                     ...         ...                           ...
# 211     American Foxhounds         187                      Foxhound
# 212     American Foxhounds         187                         Hound
# 213               Sloughis         188                       Sloughi
# 214      English Foxhounds         189             English Foxhounds
# 215   Norwegian Lundehunds         190           Norwegian Lundehund
#
#            Group1      Group2  MaleWtKg  \
# 0        Sporting         Gun      32.0
# 1        Sporting         Gun      32.0
# ...

# %%
akc_updated = pd.DataFrame(merged_df, columns = ['BreedName','Breed', 'breed_rank'])

# %%
akc_updated.head()
# Out:
#                       BreedName                  Breed  breed_rank
# 0      Black Labrador Retriever  Retrievers (Labrador)           1
# 1  Chocolate Labrador Retriever  Retrievers (Labrador)           1
# 2            Labrador Retriever  Retrievers (Labrador)           1
# 3     Yellow Labrador Retriever  Retrievers (Labrador)           1
# 4           German Shepherd Dog   German Shepherd Dogs           2

# %%
akc_updated.to_csv("akc_updated.csv")

# %%
df_updated = pd.DataFrame(merged_df, columns = ['BreedName', 'Group1', 'Group2', 'MaleWtKg','Temperment', 'AvgPupPrice', 'Intelligence', 'Watchdog'])

# %%
df_updated.head()
# Out:
#                       BreedName    Group1   Group2  MaleWtKg  \
# 0      Black Labrador Retriever  Sporting      Gun      32.0
# 1  Chocolate Labrador Retriever  Sporting      Gun      32.0
# 2            Labrador Retriever  Sporting      Gun      32.0
# 3     Yellow Labrador Retriever  Sporting      Gun      32.0
# 4           German Shepherd Dog   Herding  Herding      35.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 1  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 2  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 3  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 4  Alert, Confident, Courageous, Curious, Intelli...       1400.0
#
#    Intelligence  Watchdog
# 0           7.0       3.0
# 1           7.0       3.0
# 2           7.0       3.0
# 3           7.0       3.0
# 4           3.0       6.0

# %%
df_updated
# Out:
#                         BreedName        Group1      Group2  MaleWtKg  \
# 0        Black Labrador Retriever      Sporting         Gun      32.0
# 1    Chocolate Labrador Retriever      Sporting         Gun      32.0
# 2              Labrador Retriever      Sporting         Gun      32.0
# 3       Yellow Labrador Retriever      Sporting         Gun      32.0
# 4             German Shepherd Dog       Herding     Herding      35.0
# ..                            ...           ...         ...       ...
# 211                      Foxhound         Hound  Scenthound      32.0
# 212                         Hound         Hound  Scenthound      32.0
# 213                       Sloughi         Hound       Sight      28.0
# 214             English Foxhounds           NaN         NaN       NaN
# 215           Norwegian Lundehund  Non Sporting    Northern       8.0
#
#                                             Temperment  AvgPupPrice  \
# ...

# %%
df_updated.to_csv("df_updated")

# %%
nyc_df=pd.read_csv("./2017.csv")
nyc_df
# Out:
#                                           LicenseType               Breed  \
# 0                        Dog Individual Spayed Female        BICHON FRISE
# 1      Dog Senior Citizen or Disability Spayed Female           CHIHUAHUA
# 2                        Dog Individual Spayed Female             LAB MIX
# 3                                 Dog Individual Male           DACHSHUND
# 4                        Dog Individual Spayed Female           DACHSHUND
# ...                                               ...                 ...
# 21722                           Dog Individual Female               BOXER
# 21723                    Dog Individual Spayed Female               MIXED
# 21724                             Dog Individual Male  LABRADOR RETRIEVER
# 21725                           Dog Individual Female        GER SHEPHERD
# 21726  Dog Senior Citizen or Disability Neutered Male           CHIHUAHUA
#
#                    Color     DogName  OwnerZip  ExpYear        ValidDate
# ...

# %%
nyc_df["Breed"].value_counts()
# Out:
# MIXED                 2300
# LABRADOR RETRIEVER    1379
# LAB MIX               1194
# GER SHEPHERD           748
# GOLDEN RETRIEVER       694
#                       ...
# KARELIAN BEAR DOG        1
# FIELD SPANIEL            1
# BELG SHEPHERD            1
# IRISH TERRIER            1
# FILA BRASILEIRO          1
# Name: Breed, Length: 265, dtype: int64

# %%
pop_select=df.loc[df['BreedName']=='Boxer']
pop_select
# Out:
#    BreedName   Group1    Group2  MaleWtKg  \
# 44     Boxer  Working  Guardian      30.0
#
#                                            Temperment  AvgPupPrice  \
# 44  Brave, Bright, Confident, Energetic, Fearless,...        900.0
#
#     Intelligence  Watchdog  PopularityUS2017
# 44          49.0       5.0              11.0

# %%
pop_select=nyc_df.loc[nyc_df['Breed']=='Tag']
pop_select
# Out:
#                                           LicenseType Breed        Color  \
# 422                      Dog Individual Neutered Male   Tag        MULTI
# 689                      Dog Individual Neutered Male   Tag      BRINDLE
# 781    Dog Senior Citizen or Disability Spayed Female   Tag      SPOTTED
# 861                      Dog Individual Spayed Female   Tag        WHITE
# 1306                     Dog Individual Spayed Female   Tag  WHITE/BLACK
# ...                                               ...   ...          ...
# 21683  Dog Senior Citizen or Disability Spayed Female   Tag  WHITE/BROWN
# 21684                    Dog Individual Neutered Male   Tag        BLACK
# 21685  Dog Senior Citizen or Disability Neutered Male   Tag        BLACK
# 21690         Dog Senior Citizen or Disability Female   Tag        BLACK
# 21698                    Dog Individual Spayed Female   Tag        BROWN
#
#        DogName  OwnerZip  ExpYear        ValidDate
# ...

# %%
nyc_df['Breed'] = nyc_df['Breed'].str.title()
nyc_df
# Out:
#                                           LicenseType               Breed  \
# 0                        Dog Individual Spayed Female        Bichon Frise
# 1      Dog Senior Citizen or Disability Spayed Female           Chihuahua
# 2                        Dog Individual Spayed Female             Lab Mix
# 3                                 Dog Individual Male           Dachshund
# 4                        Dog Individual Spayed Female           Dachshund
# ...                                               ...                 ...
# 21722                           Dog Individual Female               Boxer
# 21723                    Dog Individual Spayed Female               Mixed
# 21724                             Dog Individual Male  Labrador Retriever
# 21725                           Dog Individual Female        Ger Shepherd
# 21726  Dog Senior Citizen or Disability Neutered Male           Chihuahua
#
#                    Color     DogName  OwnerZip  ExpYear        ValidDate
# ...

# %%
for i, row in nyc_df.iterrows():
    value = "German Shepherd Dog"
    if nyc_df.loc[i, "Breed"]=="Ger Shepherd":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Labrador Retriever"
    if nyc_df.loc[i, "Breed"]=="Lab Mix":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Polish Lowland Sheepdog"
    if nyc_df.loc[i, "Breed"]=="Polish Lowlnd Sheep":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Irish Setter"
    if nyc_df.loc[i, "Breed"]=="Irish Red&White Set":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Pit Bull Terrier"
    if nyc_df.loc[i, "Breed"]=="Am Pit Bull Terrier":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Beagle"
    if nyc_df.loc[i, "Breed"]=="Beagle Mix":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "German Shepherd"
    if nyc_df.loc[i, "Breed"]=="Ger Shepherd Mix":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Terrier"
    if nyc_df.loc[i, "Breed"]=="Terrier Mix":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Pit Bull Terrier"
    if nyc_df.loc[i, "Breed"]=="Am Pitt Bull Mix":
        nyc_df.at[i,'Breed'] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Yorkshire Terrier Yorkie"
    if nyc_df.loc[i, "Breed"]=="Yorkshire Terrier Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Siberian Huskie"
    if nyc_df.loc[i, "Breed"]=="Sib Husky":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Boxer"
    if nyc_df.loc[i, "Breed"]=="Boxer Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Jack Russell Terrier (Parson Russell Terrier)"
    if nyc_df.loc[i, "Breed"]=="Parson Russell Terrier":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Jack Russell Terrier (Parson Russell Terrier)"
    if nyc_df.loc[i, "Breed"]=="Jack Russel Terr":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Miniature Schnauzer"
    if nyc_df.loc[i, "Breed"]=="Schnauzer Min":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Shetland Sheepdog Sheltie"
    if nyc_df.loc[i, "Breed"]=="Shetland Sheepdog":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Chihuahua"
    if nyc_df.loc[i, "Breed"]=="Chihuahua Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Border Collie"
    if nyc_df.loc[i, "Breed"]=="Bord Collie":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Poodle"
    if nyc_df.loc[i, "Breed"]=="Poodle Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Austrialian Shepherd"
    if nyc_df.loc[i, "Breed"]=="Aus Shepherd":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "English Bulldog"
    if nyc_df.loc[i, "Breed"]=="Eng Bulldog":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "West Highland White Terrier Westie"
    if nyc_df.loc[i, "Breed"]=="W Hghlnd Wh Terrier":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Shih Tzu"
    if nyc_df.loc[i, "Breed"]=="Shih Tzu Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Cavalier King Charles Spaniel"
    if nyc_df.loc[i, "Breed"]=="Cav King Char Spani":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Miniature Pinscher"
    if nyc_df.loc[i, "Breed"]=="Min Pinscher":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Toy Poodle"
    if nyc_df.loc[i, "Breed"]=="Poodle Toy":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "English Springer Spaniel"
    if nyc_df.loc[i, "Breed"]=="Eng Springer Spanie":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "German Shorthaired Pointer"
    if nyc_df.loc[i, "Breed"]=="Ger Shorthair Point":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Standard Poodle"
    if nyc_df.loc[i, "Breed"]=="Poodle Standard":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Bishon Frise"
    if nyc_df.loc[i, "Breed"]=="Bishon Frise Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Collie"
    if nyc_df.loc[i, "Breed"]=="Collie Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Old English Sheepdog"
    if nyc_df.loc[i, "Breed"]=="Old Eng Sheepdog":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Cocker Spaniel"
    if nyc_df.loc[i, "Breed"]=="Cocker Spaniel Mix":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "American Eskimo Dog"
    if nyc_df.loc[i, "Breed"]=="Am Eskimo Dog":
        nyc_df.at[i,"Breed"] = value

# %%
for i, row in nyc_df.iterrows():
    value = "Miniature Poodle"
    if nyc_df.loc[i, "Breed"]=="Poodle Min":
        nyc_df.at[i,"Breed"] = value

# %%
nyc_df.drop(nyc_df[nyc_df['Breed'] == "Mixed"].index, inplace = True)

# %%
nyc_df.drop(nyc_df[nyc_df['Breed'] == "Tag"].index, inplace = True)

# %%
top_counts = nyc_df["Breed"].value_counts().to_frame()

# %%
top_counts.head(50)
# Out:
#                                                Breed
# Labrador Retriever                              2573
# Beagle                                           965
# Pit Bull Terrier                                 836
# Chihuahua                                        830
# Shih Tzu                                         771
# German Shepherd Dog                              748
# Golden Retriever                                 694
# Boxer                                            639
# Yorkshire Terrier                                495
# Dachshund                                        444
# Terrier                                          348
# German Shepherd                                  315
# Maltese                                          271
# Cocker Spaniel                                   264
# Pomeranian                                       252
# Goldendoodle                                     245
# Pug                                              239
# ...

# %%
merged_nyc = nyc_df.merge(df, how="left", left_on="Breed", right_on="BreedName")
merged_nyc.head(200)
# Out:
#                                         LicenseType               Breed  \
# 0                      Dog Individual Spayed Female        Bichon Frise
# 1    Dog Senior Citizen or Disability Spayed Female           Chihuahua
# 2                      Dog Individual Spayed Female  Labrador Retriever
# 3                               Dog Individual Male           Dachshund
# 4                      Dog Individual Spayed Female           Dachshund
# ..                                              ...                 ...
# 195                             Dog Individual Male           Dachshund
# 196  Dog Senior Citizen or Disability Spayed Female             Maltese
# 197                    Dog Individual Spayed Female           Dachshund
# 198                    Dog Individual Spayed Female              Collie
# 199                    Dog Individual Spayed Female           Shiba Inu
#
#                  Color       DogName  OwnerZip  ExpYear        ValidDate  \
# ...

# %%
merged_nyc.isna().sum().sum()
# Out:
# 40723

# %%
merged_nyc["Breed"].value_counts()
# Out:
# Labrador Retriever    2573
# Beagle                 965
# Pit Bull Terrier       836
# Chihuahua              830
# Shih Tzu               771
#                       ...
# Polish Hound             1
# Belg Shepherd            1
# Treeing Cur              1
# Jindo                    1
# Carolina Dog             1
# Name: Breed, Length: 253, dtype: int64

# %%
merged_nyc.to_csv("merged_nyc")

# %%
#df.loc[df.PopularityUS2017 == 68.0, 'BreedName'] = "Cardigan Welsh Corgis"
#Changed Welsh Corgi, Cardigan, Pembroke, Corgi to Cardigan Welsh Corgis
