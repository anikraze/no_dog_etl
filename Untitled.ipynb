# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\TriciaToffey\\desktop\\GitHubs\\ETL_Project'

# %%
df_orig=pd.read_csv("./Resources/dog_breed_characteristics.csv")
df_orig.head(25)
# Out:
#                             BreedName AltBreedName        Group1      Group2  \
# 0                       Affenpinscher          NaN           Toy   Companion
# 1                        Afghan Hound          NaN      Sporting       Sight
# 2                 African Hunting Dog          NaN           NaN         NaN
# 3                    Airedale Terrier     Airedale       Terrier     Terrier
# 4                              Akbash          NaN       Working    Guardian
# 5                               Akita          NaN       Working     Herding
# 6                    Alaskan Malamute     Malamute       Working    Northern
# 7                    American Bulldog          NaN       Working    Guardian
# 8                 American Eskimo Dog          NaN  Non Sporting    Northern
# 9           American Hairless Terrier          NaN       Terrier     Terrier
# 10     American Staffordshire Terrier          NaN       Terrier     Terrier
# ...

# %%
df_orig.columns
# Out:
# Index(['BreedName', 'AltBreedName', 'Group1', 'Group2', 'MaleWtKg',
#        'Temperment', 'AvgPupPrice', 'Intelligence', 'Watchdog',
#        'MalaysiaGuardedDog', 'MalaysiaProhibitedDog', 'MalaysiaPopularity',
#        'PopularityUS2017'],
#       dtype='object')

# %%
df=df_orig.drop(["AltBreedName", "MalaysiaGuardedDog", "MalaysiaProhibitedDog", "MalaysiaPopularity"], axis=1)

# %%
df.head()
# Out:
#              BreedName    Group1     Group2  MaleWtKg  \
# 0        Affenpinscher       Toy  Companion       4.0
# 1         Afghan Hound  Sporting      Sight      28.0
# 2  African Hunting Dog       NaN        NaN      23.0
# 3     Airedale Terrier   Terrier    Terrier      26.0
# 4               Akbash   Working   Guardian      53.0
#
#                                           Temperment  AvgPupPrice  \
# 0  Active, Adventurous, Curious, Fun-loving, Play...       1000.0
# 1     Aloof, Clownish, Dignified, Happy, Independent       2250.0
# 2                                               Wild          NaN
# 3  Alert, Confident, Courageous, Friendly, Intell...        700.0
# 4  Affectionate, Alert, Courageous, Independent, ...        600.0
#
#    Intelligence  Watchdog  PopularityUS2017
# 0          37.0       1.0             147.0
# 1          79.0       1.0              93.0
# 2           NaN       NaN               NaN
# 3          29.0       4.0              55.0
# ...

# %%
df.sort_values(by=['PopularityUS2017'])
# Out:
#                         BreedName    Group1    Group2  MaleWtKg  \
# 247     Yellow Labrador Retriever  Sporting       Gun      32.0
# 64   Chocolate Labrador Retriever  Sporting       Gun      32.0
# 31       Black Labrador Retriever  Sporting       Gun      32.0
# 143            Labrador Retriever  Sporting       Gun      32.0
# 209                      Shepherd   Herding   Herding      35.0
# ..                            ...       ...       ...       ...
# 198                   Sarplaninac   Working  Guardian      33.0
# 218       South Russian Ovtcharka   Herding   Herding      49.0
# 225                Thai Ridgeback     Hound     Sight      28.0
# 229                      Tosa Inu   Working  Guardian      65.0
# 249                   Mixed Breed       NaN       NaN       NaN
#
#                                             Temperment  AvgPupPrice  \
# 247  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# ...

# %%
pop_select=df[df["PopularityUS2017"]==1]
pop_select
# Out:
#                         BreedName    Group1 Group2  MaleWtKg  \
# 31       Black Labrador Retriever  Sporting    Gun      32.0
# 64   Chocolate Labrador Retriever  Sporting    Gun      32.0
# 143            Labrador Retriever  Sporting    Gun      32.0
# 247     Yellow Labrador Retriever  Sporting    Gun      32.0
#
#                                             Temperment  AvgPupPrice  \
# 31   Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 64   Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 143  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
# 247  Affectionate, Alert, Cheerful, Energetic, Frie...       1500.0
#
#      Intelligence  Watchdog  PopularityUS2017
# 31            7.0       3.0               1.0
# 64            7.0       3.0               1.0
# 143           7.0       3.0               1.0
# 247           7.0       3.0               1.0

# %%
pop_select=df.loc[df['PopularityUS2017']<=191]
pop_select
# Out:
#                            BreedName        Group1     Group2  MaleWtKg  \
# 0                      Affenpinscher           Toy  Companion       4.0
# 1                       Afghan Hound      Sporting      Sight      28.0
# 3                   Airedale Terrier       Terrier    Terrier      26.0
# 5                              Akita       Working    Herding      44.0
# 6                   Alaskan Malamute       Working   Northern      40.0
# ..                               ...           ...        ...       ...
# 244     Wire-haired Pointing Griffon      Sporting        Gun      25.0
# 245               Wirehaired Terrier       Terrier    Terrier       7.0
# 246  Xoloitzcuintle/Mexican Hairless  Non Sporting      Sight      11.0
# 247        Yellow Labrador Retriever      Sporting        Gun      32.0
# 248         Yorkshire Terrier Yorkie           Toy  Companion       3.0
#
#                                             Temperment  AvgPupPrice  \
# ...

# %%
popularity_df=df.sort_values(by=['PopularityUS2017'])

# %%
popularity_df[['BreedName', 'PopularityUS2017']]
# Out:
#                         BreedName  PopularityUS2017
# 247     Yellow Labrador Retriever               1.0
# 64   Chocolate Labrador Retriever               1.0
# 31       Black Labrador Retriever               1.0
# 143            Labrador Retriever               1.0
# 209                      Shepherd               2.0
# ..                            ...               ...
# 198                   Sarplaninac               NaN
# 218       South Russian Ovtcharka               NaN
# 225                Thai Ridgeback               NaN
# 229                      Tosa Inu               NaN
# 249                   Mixed Breed               NaN
#
# [250 rows x 2 columns]

# %%
popularity_df = popularity_df.loc[popularity_df['PopularityUS2017'].notnull()]

# %%
popularity_df
# Out:
#                         BreedName        Group1      Group2  MaleWtKg  \
# 247     Yellow Labrador Retriever      Sporting         Gun      32.0
# 64   Chocolate Labrador Retriever      Sporting         Gun      32.0
# 31       Black Labrador Retriever      Sporting         Gun      32.0
# 143            Labrador Retriever      Sporting         Gun      32.0
# 209                      Shepherd       Herding     Herding      35.0
# ..                            ...           ...         ...       ...
# 168                    Otterhound         Hound  Scenthound      41.0
# 101                      Foxhound         Hound  Scenthound      32.0
# 119                         Hound         Hound  Scenthound      32.0
# 216                       Sloughi         Hound       Sight      28.0
# 164           Norwegian Lundehund  Non Sporting    Northern       8.0
#
#                                             Temperment  AvgPupPrice  \
# ...

# %%
popularity_df["PopularityUS2017"].value_counts()
# Out:
# 1.0      4
# 118.0    4
# 68.0     4
# 2.0      3
# 12.0     2
#         ..
# 120.0    1
# 119.0    1
# 116.0    1
# 114.0    1
# 91.0     1
# Name: PopularityUS2017, Length: 177, dtype: int64
